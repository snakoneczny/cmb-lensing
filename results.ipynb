# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from evaluation import evaluate

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 80

sns.set(style='ticks')
sns.set_palette('cubehelix')

# %% [markdown]
# # M500c higher than 1.5

# %%
exp_output = pd.read_csv('predictions/min_m500c_1_2019-07-22_16:53:50.csv')
exp_output.shape
# Out:
# (1150, 3)

# %%
evaluate(exp_output.loc[exp_output['test'] == 'random'], mass_max=4)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.3079
# MSE: 0.2973
# MAE: 0.4410
# Relative error mean: 0.1190, sigma: 0.3107
# Log residuals mean: 0.0689, sigma: 0.3055
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %% [markdown]
# # M200b higher than 2.5

# %%
exp_output = pd.read_csv('predictions/min_mass_2.5_2019-07-22_16:31:53.csv')
exp_output.shape
# Out:
# (686, 3)

# %%
evaluate(exp_output.loc[exp_output['test'] == 'random'], mass_max=4)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.3810
# MSE: 0.3266
# MAE: 0.4420
# Relative error mean: 0.0831, sigma: 0.2896
# Log residuals mean: 0.0435, sigma: 0.2731
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %% [markdown]
# # M200b higher than 1.5

# %%
exp_output = pd.read_csv('predictions/no_low_mass_2019-07-22_16:11:59.csv')
exp_output.shape
# Out:
# (1874, 3)

# %%
evaluate(exp_output.loc[exp_output['test'] == 'random'], mass_max=2)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.2208
# MSE: 0.1840
# MAE: 0.3278
# Relative error mean: 0.1142, sigma: 0.3274
# Log residuals mean: 0.0626, sigma: 0.3090
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %% [markdown]
# # Mass relevant test

# %%
exp_output = pd.read_csv('predictions/multi_test_2019-07-22_14:03:54.csv')

# %%
evaluate(exp_output.loc[exp_output['test'] == 'random'], mass_max=2)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.1334
# MSE: 0.1155
# MAE: 0.2590
# Relative error mean: 0.1171, sigma: 0.3567
# Log residuals mean: 0.0560, sigma: 0.3404
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %%
evaluate(exp_output.loc[exp_output['test'] == 'high'], mass_max=6)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 1.8975
# MSE: 6.4650
# MAE: 2.1650
# Relative error mean: -0.6285, sigma: 0.0991
# Log residuals mean: -1.0312, sigma: 0.3020
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %%
evaluate(exp_output.loc[exp_output['test'] == 'low'], mass_max=1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.0041
# MSE: 0.2089
# MAE: 0.4442
# Relative error mean: 1.2478, sigma: 0.5699
# Log residuals mean: 0.7846, sigma: 0.2145
# /Users/snakoneczny/workspace/cmb_lensing/venv/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %% [markdown]
# # Random test

# %%
exp_output = pd.read_csv('predictions/random_test_2019-07-19_14:35:31.csv')
evaluate(exp_output, mass_max=2)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# MSE when estimating mean M500c value: 0.4969
# MSE: 0.3283
# MAE: 0.3722
# Relative error mean: 0.2261, sigma: 0.5343
# Log residuals mean: 0.1129, sigma: 0.4363
